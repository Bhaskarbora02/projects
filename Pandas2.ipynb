# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\LENOVO\Downloads\Titanic_Survival_Train.xls",index_col=0,header=0)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df.shape
# Out:
# (891, 11)

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Sex'].mode()
# Out:
# 0    male
# dtype: object

# %%
df['Cabin'].mode()[0]
# Out:
# 'B96 B98'

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Pclass'].value_counts(normalize=True)
# Out:
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: Pclass, dtype: float64

# %%
pd.crosstab(df['Sex'],df['Survived'],margins=True,margins_name='Total') ### first value will become row and 2nd value will become column
# Out:
# Survived    0    1  Total
# Sex
# female     81  233    314
# male      468  109    577
# Total     549  342    891

# %%
pd.crosstab(df['Sex'],df['Pclass'],margins=True,margins_name='Total') ### first value will become row and 2nd value will become column
# Out:
# Pclass    1    2    3  Total
# Sex
# female   94   76  144    314
# male    122  108  347    577
# Total   216  184  491    891

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.iloc[0:10,0:]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %%
df.loc[21:100,['Survived','Name']]
# Out:
#              Survived                                  Name
# PassengerId
# 21                  0                  Fynney, Mr. Joseph J
# 22                  1                 Beesley, Mr. Lawrence
# 23                  1           McGowan, Miss. Anna "Annie"
# 24                  1          Sloper, Mr. William Thompson
# 25                  0         Palsson, Miss. Torborg Danira
# ...               ...                                   ...
# 96                  0           Shorney, Mr. Charles Joseph
# 97                  0             Goldschmidt, Mr. George B
# 98                  1       Greenfield, Mr. William Bertram
# 99                  1  Doling, Mrs. John T (Ada Julia Bone)
# 100                 0                     Kantor, Mr. Sinai
#
# [80 rows x 2 columns]

# %%
df_agemorethan60=df[df['Age']>60]

# %%
df_agemorethan60
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 34                  0       2                      Wheadon, Mr. Edward H
# 55                  0       1             Ostby, Mr. Engelhart Cornelius
# 97                  0       1                  Goldschmidt, Mr. George B
# 117                 0       3                       Connors, Mr. Patrick
# 171                 0       1                  Van der hoef, Mr. Wyckoff
# 253                 0       1                  Stead, Mr. William Thomas
# 276                 1       1          Andrews, Miss. Kornelia Theodosia
# 281                 0       3                           Duane, Mr. Frank
# 327                 0       3                  Nysveen, Mr. Johan Hansen
# 439                 0       1                          Fortune, Mr. Mark
# 457                 0       1                  Millet, Mr. Francis Davis
# 484                 1       3                     Turkula, Mrs. (Hedwig)
# ...

# %%
df_agemorethan60.shape
# Out:
# (22, 11)

# %%
df_male=df[df['Sex']=='male']

# %%
df_male
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 7                   0       1         McCarthy, Mr. Timothy J  male  54.0
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
# ...               ...     ...                             ...   ...   ...
# 884                 0       2   Banfield, Mr. Frederick James  male  28.0
# 885                 0       3          Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2           Montvila, Rev. Juozas  male  27.0
# 890                 1       1           Behr, Mr. Karl Howell  male  26.0
# 891                 0       3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
df1=df[(df['Age']>=60)&(df['Sex']=='male')&(df['Survived']==1)]

# %%
df1
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 571                 1       2                    Harris, Mr. George  male
# 588                 1       1      Frolicher-Stehli, Mr. Maxmillian  male
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson  male
#
#               Age  SibSp  Parch       Ticket  Fare Cabin Embarked
# PassengerId
# 571          62.0      0      0  S.W./PP 752  10.5   NaN        S
# 588          60.0      1      1        13567  79.2   B41        C
# 631          80.0      0      0        27042  30.0   A23        S

# %%
###NULL VALUES
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# #### 2 options for dealing with null values
# if there is more than 10 % of data as a null values we can't proceed with dropping the 
# null values as there would be huge dataloss which would affect our final result.

# if the data or column that we are working is important for predicting results than too i can't drop the null values.
###if we have even distribution of data then we may fill the null values with mean and for uneven 
#distribution we may fill null values with median
##For characters or object data we need to fill it with mode value

# 1. Either we can fill the null values---->
# 2. Either we can drop the null values---->

# %%
#df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
#df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#df.drop(['Cabin'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#df['Cabin'].dropna()

# %%
#df.isnull().sum()

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
#df=df.dropna(how='any',subset=['Cabin'])

# %%
df=df.dropna(how='any',subset=['Embarked','Age'])

# %%
df.shape
# Out:
# (712, 11)

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       529
# Embarked      0
# dtype: int64

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
#TYPES OF VARIABLES

# THERE ARE 2 TYPES OF VARIABLES

# 1. QUANTITATIVE/NUMERICAL
# 2. QUALITATIVE/CATEGORICAL


# QUANTITATIVE

# 1. DISCRETE
#IT WILL ALWAYS BE AN INTEGER 
#will always be countable parameters
#population,no.of cars on road

# 2. CONTINOUS
#IT MAY OR MAY NOT BE INTEGER
#will always be measureable parameters
#volume,#densite#height/weight

# QUALITATIVE

# 1.BINOMIAL
##when we have 2 outcomes it will be binomial
#T/F,W/L,H/T,S/DS,Y/N

# # 2.NOMINAL
# WHEN WE HAVE MORE THAN 2 OUTCOMES IT WILL BE NOMINAL
# IT MAY OR MAY NOT BE IN ORDER 
# IF WE CHANGE THE ORDER NO EFFECT ON MEANINGS
# #NAME,APPAREL  CATEGORY

# # 3.ODINAL
# WHEN WE HAVE MORE THAN 2 OUTCOMES IT WILL BE ODINAL
# BUT IT NEEDS TO BE IN ORDER
# IF WE CHANGE THE ORDER THE MEANINGS CHANGES
# ##MOVIE RATINGS,RANKS OF STUDENTS,SIZE OF CLOTHES

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...
